# %% [markdown]
# # Проект по курсу Машинное обучение
# ### 1курс маг. 6 группа. Полтавский Артем, Мезга Александр
# ### Датасет: https://archive.ics.uci.edu/ml/datasets/Dishonest+Internet+users+Dataset
# ### Референсная статья: https://www.hindawi.com/journals/complexity/2020/4579495/
# ### Точность предсказаний которую нужно превзойти: 93.87%

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import  confusion_matrix,accuracy_score,precision_score,recall_score,f1_score

# %%
# Загрузка данных. Первоначальный анализ

# %%
filename = "dishonest-internet-users-dataset.csv"
data= pd.read_csv(filename)
df = pd.DataFrame(data)
df
# Out:
#      ctrust  cuntrust  last  context          score
# 0         4         1     4    sport  untrustworthy
# 1         4         1     4    sport  untrustworthy
# 2         1         4     4    sport    trustworthy
# 3         2         1     4    sport    trustworthy
# 4         3         1     4    sport    trustworthy
# 5         4         1     4    sport  untrustworthy
# 6         1         4     4    sport    trustworthy
# 7         2         1     4    sport    trustworthy
# 8         3         1     4    sport    trustworthy
# 9         4         1     4    sport  untrustworthy
# 10        1         4     4    sport    trustworthy
# 11        2         1     4    sport    trustworthy
# 12        3         1     4    sport    trustworthy
# 13        4         1     4    sport  untrustworthy
# 14        1         4     4    sport    trustworthy
# 15        1         4     4    sport    trustworthy
# 16        2         1     4    sport    trustworthy
# 17        3         1     4    sport    trustworthy
# 18        4         1     4    sport  untrustworthy
# 19        1         3     4    sport    trustworthy
# 20        2         1     4    sport    trustworthy
# 21        3         1     4    sport    trustworthy
# 22        4         1     4    sport  untrustworthy
# 23        1         3     4    sport    trustworthy
# 24        2         1     4    sport    trustworthy
# 25        3         1     4    sport    trustworthy
# 26        4         1     4    sport  untrustworthy
# 27        1         3     4    sport    trustworthy
# 28        2         1     4    sport    trustworthy
# 29        3         1     4    sport    trustworthy
# ..      ...       ...   ...      ...            ...
# 292       1         1     1  holiday    trustworthy
# 293       2         1     2  holiday  untrustworthy
# 294       2         1     2  holiday  untrustworthy
# 295       1         1     1  holiday    trustworthy
# 296       1         1     1  holiday    trustworthy
# 297       1         1     1  holiday    trustworthy
# 298       2         1     2  holiday  untrustworthy
# 299       2         1     2  holiday  untrustworthy
# 300       1         1     1  holiday    trustworthy
# 301       1         1     1  holiday    trustworthy
# 302       1         1     1  holiday    trustworthy
# 303       2         1     2  holiday  untrustworthy
# 304       1         1     1  holiday    trustworthy
# 305       1         1     1  holiday    trustworthy
# 306       1         1     1  holiday    trustworthy
# 307       2         1     2  holiday  untrustworthy
# 308       2         1     2  holiday  untrustworthy
# 309       1         1     1  holiday    trustworthy
# 310       1         1     1  holiday    trustworthy
# 311       1         1     1  holiday    trustworthy
# 312       2         1     2  holiday  untrustworthy
# 313       1         1     1  holiday    trustworthy
# 314       1         1     1  holiday    trustworthy
# 315       1         1     1  holiday    trustworthy
# 316       2         1     2  holiday  untrustworthy
# 317       2         1     2  holiday  untrustworthy
# 318       1         1     1  holiday    trustworthy
# 319       1         1     1  holiday    trustworthy
# 320       1         1     1  holiday    trustworthy
# 321       2         1     2  holiday  untrustworthy
#
# [322 rows x 5 columns]

# %%
df.describe()
# Out:
#            ctrust    cuntrust        last
# count  322.000000  322.000000  322.000000
# mean     2.195652    1.527950    2.366460
# std      1.273592    1.105422    1.347384
# min      1.000000    1.000000    1.000000
# 25%      1.000000    1.000000    1.000000
# 50%      2.000000    1.000000    2.000000
# 75%      4.000000    1.000000    4.000000
# max      4.000000    5.000000    4.000000

# %%
print('ctrust',df.ctrust.unique())
print('cuntrust',df.cuntrust.unique())
print('last',df['last'].unique())
print('context',df.context.unique())
print('score',df.score.unique())
# Out:
# ctrust [4 1 2 3]
# cuntrust [1 4 3 5]
# last [4 1 3 2]
# context ['sport' 'game' 'ECommerce' 'holiday']
# score ['untrustworthy' 'trustworthy']

# %% [markdown]
# # Перевод признаков из строк в категориальные значения

# %%
df['score'].replace({'untrustworthy':0,'trustworthy':1},inplace=True)
df
# Out:
#      ctrust  cuntrust  last  context  score
# 0         4         1     4    sport      0
# 1         4         1     4    sport      0
# 2         1         4     4    sport      1
# 3         2         1     4    sport      1
# 4         3         1     4    sport      1
# 5         4         1     4    sport      0
# 6         1         4     4    sport      1
# 7         2         1     4    sport      1
# 8         3         1     4    sport      1
# 9         4         1     4    sport      0
# 10        1         4     4    sport      1
# 11        2         1     4    sport      1
# 12        3         1     4    sport      1
# 13        4         1     4    sport      0
# 14        1         4     4    sport      1
# 15        1         4     4    sport      1
# 16        2         1     4    sport      1
# 17        3         1     4    sport      1
# 18        4         1     4    sport      0
# 19        1         3     4    sport      1
# 20        2         1     4    sport      1
# 21        3         1     4    sport      1
# 22        4         1     4    sport      0
# 23        1         3     4    sport      1
# 24        2         1     4    sport      1
# 25        3         1     4    sport      1
# 26        4         1     4    sport      0
# 27        1         3     4    sport      1
# 28        2         1     4    sport      1
# 29        3         1     4    sport      1
# ..      ...       ...   ...      ...    ...
# 292       1         1     1  holiday      1
# 293       2         1     2  holiday      0
# 294       2         1     2  holiday      0
# 295       1         1     1  holiday      1
# 296       1         1     1  holiday      1
# 297       1         1     1  holiday      1
# 298       2         1     2  holiday      0
# 299       2         1     2  holiday      0
# 300       1         1     1  holiday      1
# 301       1         1     1  holiday      1
# 302       1         1     1  holiday      1
# 303       2         1     2  holiday      0
# 304       1         1     1  holiday      1
# 305       1         1     1  holiday      1
# 306       1         1     1  holiday      1
# 307       2         1     2  holiday      0
# 308       2         1     2  holiday      0
# 309       1         1     1  holiday      1
# 310       1         1     1  holiday      1
# 311       1         1     1  holiday      1
# 312       2         1     2  holiday      0
# 313       1         1     1  holiday      1
# 314       1         1     1  holiday      1
# 315       1         1     1  holiday      1
# 316       2         1     2  holiday      0
# 317       2         1     2  holiday      0
# 318       1         1     1  holiday      1
# 319       1         1     1  holiday      1
# 320       1         1     1  holiday      1
# 321       2         1     2  holiday      0
#
# [322 rows x 5 columns]

# %%
df['context'].replace({'sport':1,'game':2,'ECommerce':3,'holiday':4},inplace=True)
df
# Out:
#      ctrust  cuntrust  last  context  score
# 0         4         1     4        1      0
# 1         4         1     4        1      0
# 2         1         4     4        1      1
# 3         2         1     4        1      1
# 4         3         1     4        1      1
# 5         4         1     4        1      0
# 6         1         4     4        1      1
# 7         2         1     4        1      1
# 8         3         1     4        1      1
# 9         4         1     4        1      0
# 10        1         4     4        1      1
# 11        2         1     4        1      1
# 12        3         1     4        1      1
# 13        4         1     4        1      0
# 14        1         4     4        1      1
# 15        1         4     4        1      1
# 16        2         1     4        1      1
# 17        3         1     4        1      1
# 18        4         1     4        1      0
# 19        1         3     4        1      1
# 20        2         1     4        1      1
# 21        3         1     4        1      1
# 22        4         1     4        1      0
# 23        1         3     4        1      1
# 24        2         1     4        1      1
# 25        3         1     4        1      1
# 26        4         1     4        1      0
# 27        1         3     4        1      1
# 28        2         1     4        1      1
# 29        3         1     4        1      1
# ..      ...       ...   ...      ...    ...
# 292       1         1     1        4      1
# 293       2         1     2        4      0
# 294       2         1     2        4      0
# 295       1         1     1        4      1
# 296       1         1     1        4      1
# 297       1         1     1        4      1
# 298       2         1     2        4      0
# 299       2         1     2        4      0
# 300       1         1     1        4      1
# 301       1         1     1        4      1
# 302       1         1     1        4      1
# 303       2         1     2        4      0
# 304       1         1     1        4      1
# 305       1         1     1        4      1
# 306       1         1     1        4      1
# 307       2         1     2        4      0
# 308       2         1     2        4      0
# 309       1         1     1        4      1
# 310       1         1     1        4      1
# 311       1         1     1        4      1
# 312       2         1     2        4      0
# 313       1         1     1        4      1
# 314       1         1     1        4      1
# 315       1         1     1        4      1
# 316       2         1     2        4      0
# 317       2         1     2        4      0
# 318       1         1     1        4      1
# 319       1         1     1        4      1
# 320       1         1     1        4      1
# 321       2         1     2        4      0
#
# [322 rows x 5 columns]

# %%
# Разделить данные на X и y, нормализовать данные

# %%
y=data.score.values
x_data=data.drop("score",axis=1)

# %%
x=(x_data-np.min(x_data))/(np.max(x_data)-np.min(x_data))
x
# Out:
#        ctrust  cuntrust      last  context
# 0    1.000000      0.00  1.000000      0.0
# 1    1.000000      0.00  1.000000      0.0
# 2    0.000000      0.75  1.000000      0.0
# 3    0.333333      0.00  1.000000      0.0
# 4    0.666667      0.00  1.000000      0.0
# ..        ...       ...       ...      ...
# 317  0.333333      0.00  0.333333      1.0
# 318  0.000000      0.00  0.000000      1.0
# 319  0.000000      0.00  0.000000      1.0
# 320  0.000000      0.00  0.000000      1.0
# 321  0.333333      0.00  0.333333      1.0
#
# [322 rows x 4 columns]

# %%
import seaborn as sns
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import train_test_split

from tabulate import tabulate

# %%
# SVM

# %%
def calc_svm(x, y, train_size):
    x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=train_size,random_state=42)
    
    svclassifier = SVC(kernel='linear')
    svclassifier.fit(x_train, y_train)
    y_pred = svclassifier.predict(x_test)
    confu_svm=confusion_matrix(y_test,y_pred)
    accuracy_svm=accuracy_score(y_test,y_pred)
    precision_svm=precision_score(y_test,y_pred)
    recall_svm=recall_score(y_test,y_pred)
    f1_svm=f1_score(y_test,y_pred)
    return ([accuracy_svm,precision_svm,recall_svm,f1_svm], confu_svm)

# %%
# Naive Bayes

# %%
def calc_nb(x, y, train_size):
    x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=train_size,random_state=42)
    
    nb=GaussianNB()
    nb.fit(x_train,y_train)
    y_pred = nb.predict(x_test)
    confu_nb=confusion_matrix(y_test,y_pred)
    accuracy_nb=accuracy_score(y_test,y_pred)
    precision_nb=precision_score(y_test,y_pred)
    recall_nb=recall_score(y_test,y_pred)
    f1_nb=f1_score(y_test,y_pred)
    return ([accuracy_nb,precision_nb,recall_nb,f1_nb], confu_nb)

# %%
def compare_results(x, y, train_size=0.8):
    a='SVM'
    svm_results = calc_svm(x, y, train_size=train_size)
    b='Naive Bayes'
    nb_results = calc_nb(x, y, train_size=train_size)
    
    confu_nb = nb_results[1]
    result1=(a,*nb_results[0])
    
    confu_svm = svm_results[1]
    result2=(b,*svm_results[0])
    
    result=(result1,result2)
    print('confusion matrix SVM')
    print(confu_svm)

    print('confusion matrix Naive Bayes')
    print(confu_nb)

    print(tabulate(result, headers=["accuracy", "precision", "recall","f1_score"]))

# %%
compare_results(x,y,train_size=0.7)
# Out:
# confusion matrix SVM
# [[16 11]
#  [ 6 64]]
# confusion matrix Naive Bayes
# [[ 9 18]
#  [ 5 65]]
#                accuracy    precision    recall    f1_score
# -----------  ----------  -----------  --------  ----------
# SVM            0.762887     0.783133  0.928571    0.849673
# Naive Bayes    0.824742     0.853333  0.914286    0.882759

# %%
def get_stacking():
    # define the base models
    level0 = list()
    level0.append(('svm', SVC()))
    level0.append(('bayes', GaussianNB()))
    # define meta learner model
    level1 = LogisticRegression()
    # define the stacking ensemble
    model = StackingClassifier(estimators=level0, final_estimator=level1, cv=5)
    print(model)
    return model

# %%
clf = get_stacking()
# Out:
# StackingClassifier(cv=5, estimators=[('svm', SVC()), ('bayes', GaussianNB())],
#                    final_estimator=LogisticRegression())

# %%
stack_results = []
for train_size in [i*0.1 for i in range(1,10)]:
    X_train,X_test,y_train,y_test=train_test_split(x,y,train_size=train_size,random_state=37)
    acc = clf.fit(X_train, y_train).score(X_test, y_test)
    stack_results.append((acc, train_size))

# %%
stack_results
# Out:
# [(0.8068965517241379, 0.1),
#  (0.9147286821705426, 0.2),
#  (0.9823008849557522, 0.30000000000000004),
#  (0.9845360824742269, 0.4),
#  (0.9875776397515528, 0.5),
#  (0.9844961240310077, 0.6000000000000001),
#  (1.0, 0.7000000000000001),
#  (1.0, 0.8),
#  (1.0, 0.9)]

# %%
ax = sns.pointplot(x="acc", y="train_size",
                   data=stack_results, dodge=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-2d5cb8626e5a> in <module>
# ----> 1 ax = sns.pointplot(x="acc", y="train_size",
#       2                    data=stack_results, dodge=True)
#
# ~/.ml/lib/python3.8/site-packages/seaborn/categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3328               capsize=None, ax=None, **kwargs):
#    3329
# -> 3330     plotter = _PointPlotter(x, y, hue, data, order, hue_order,
#    3331                             estimator, ci, n_boot, units, seed,
#    3332                             markers, linestyles, dodge, join, scale,
#
# ~/.ml/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize)
#    1671                  orient, color, palette, errwidth=None, capsize=None):
#    1672         """Initialize the plotter."""
# -> 1673         self.establish_variables(x, y, hue, data, orient,
#    1674                                  order, hue_order, units)
#    1675         self.establish_colors(color, palette, 1)
#
# ~/.ml/lib/python3.8/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     141             # See if we need to get variables from `data`
#     142             if data is not None:
# --> 143                 x = data.get(x, x)
#     144                 y = data.get(y, y)
#     145                 hue = data.get(hue, hue)
#
# AttributeError: 'list' object has no attribute 'get'
